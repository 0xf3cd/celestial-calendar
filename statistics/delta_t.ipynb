# %% [markdown]
# ### Statistics on Delta T Values
# - Run algorithms in `calendar::delta_t` on the test data and compare the algorithms
# - Data collected from https://maia.usno.navy.mil/ser7/deltat.data
# - Dataset refreshed 2026-08-01: monthly USNO observations through 2026-04-01
# - algo5 (#64, PR #107) added to the comparison (#108): observation-window fit
#   (2005–2026.41) + SMH-anchored extrapolation — now the library default

# %%
import common
from datetime import datetime

assert common.USNO_DATA_PATH.exists(), 'Dataset not found'

# %%
lines = filter(
  lambda l: len(l.strip()),
  common.USNO_DATA_PATH.open('r').readlines(),
)

def parse_line(line: str) -> tuple[float, float]:
  '''Parse a line from the dataset. Return (year, delta_t).'''
  year, month, day, delta_t = line.split()

  ymd: datetime = datetime(int(year), int(month), int(day))
  year_len: int = (datetime(int(year) + 1, 1, 1) - datetime(int(year), 1, 1)).days
  past_len: int = (ymd - datetime(int(year), 1, 1)).days

  fraction: float = past_len / year_len
  
  return float(year) + fraction, float(delta_t)

parsed = list(map(parse_line, lines))

# %%
parsed[::41]
# Out:
# [(1973.0849315068492, 43.4724),
#  (1976.4972677595629, 46.997),
#  (1979.9150684931508, 50.4599),
#  (1983.3287671232877, 53.3024),
#  (1986.7479452054795, 55.1898),
#  (1990.1616438356164, 56.9755),
#  (1993.5808219178082, 59.6343),
#  (1997.0, 62.295),
#  (2000.4153005464482, 63.9691),
#  (2003.8328767123287, 64.5544),
#  (2007.2465753424658, 65.2494),
#  (2010.6657534246576, 66.2349),
#  (2014.0849315068492, 67.3136),
#  (2017.495890410959, 68.8245),
#  (2020.9153005464482, 69.363),
#  (2024.3306010928961, 69.2018)]

# %%
import numpy as np
from common import (
  delta_t_algo1, delta_t_algo2, delta_t_algo3, delta_t_algo4, delta_t_algo5,
)

years    = np.array([y for y, _ in parsed])
observed = np.array([v for _, v in parsed])

vf_algo1 = np.vectorize(delta_t_algo1)
vf_algo2 = np.vectorize(delta_t_algo2)
vf_algo3 = np.vectorize(delta_t_algo3)
vf_algo4 = np.vectorize(delta_t_algo4)
vf_algo5 = np.vectorize(delta_t_algo5)

algo1_pred = vf_algo1(years)
algo2_pred = vf_algo2(years)
algo3_pred = vf_algo3(years)
algo4_pred = vf_algo4(years)
algo5_pred = vf_algo5(years)

assert (len(parsed) == len(algo1_pred) == len(algo2_pred) == len(algo3_pred)
        == len(algo4_pred) == len(algo5_pred))

# %%
import pandas as pd

df = pd.DataFrame({
  'year':     years,
  'observed': observed,
  'algo1':    algo1_pred,
  'algo2':    algo2_pred,
  'algo3':    algo3_pred,
  'algo4':    algo4_pred,
  'algo5':    algo5_pred,
})

df.iloc[300::33, :]
# Out:
#             year  observed      algo1      algo2      algo3      algo4  \
# 300  1998.084932   63.0217  62.904837  62.994011  62.994011  62.994011
# 333  2000.833333   64.0400  64.036667  64.098147  64.098147  64.098147
# 366  2003.580822   64.5371  64.586164  64.484109  64.484109  64.484109
# 399  2006.328767   64.9480  65.231507  65.182797  65.079329  64.935156
# 432  2009.084932   65.8025  66.333973  66.308186  65.886885  65.813947
# 465  2011.832877   66.5383  67.433151  67.514753  66.692033  66.551103
# 498  2014.580822   67.4989  68.532329  68.805727  67.497181  67.516171
# 531  2017.328767   68.7623  72.211767  70.181108  68.490395  68.697633
# 564  2020.084699   69.3752  76.411138  71.645263  69.576156  69.389833
# 597  2022.832877   69.1942  80.645583  73.189839  70.718996  69.197565
# 630  2025.580822   69.1219  84.926490  74.818695  71.921782  69.035864
#
#          algo5
# 300  62.994011
# 333  64.098147
# 366  64.484109
# 399  64.913647
# 432  65.830032
# 465  66.520879
# ...

# %%
from sklearn import metrics

algos = [algo1_pred, algo2_pred, algo3_pred, algo4_pred, algo5_pred]

results = []
for name, fn in [
  ('MAE',       metrics.mean_absolute_error),
  ('MSE',       metrics.mean_squared_error),
  ('RMSE',      metrics.root_mean_squared_error),
  ('R2',        metrics.r2_score),
  ('MAPE',      metrics.mean_absolute_percentage_error),
  ('Max Error', metrics.max_error),
]:
  results.append((name, *(fn(observed, pred) for pred in algos)))

pd.DataFrame(results, columns=['Metric', 'Algo1', 'Algo2', 'Algo3', 'Algo4', 'Algo5'])
# Out:
#       Metric      Algo1     Algo2     Algo3     Algo4     Algo5
# 0        MAE   1.969346  0.789383  0.244563  0.033159  0.035991
# 1        MSE  19.458707  2.554697  0.409398  0.001830  0.001982
# 2       RMSE   4.411202  1.598342  0.639842  0.042775  0.044520
# 3         R2   0.653216  0.954471  0.992704  0.999967  0.999965
# 4       MAPE   0.028834  0.011581  0.003635  0.000569  0.000612
# 5  Max Error  16.837684  6.093025  3.089220  0.134213  0.123002

# %%
import matplotlib.pyplot as plt

recent = years >= 2020.0

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(years[recent], observed[recent], 'k.', markersize=4, label='Observed (USNO)')
ax.plot(years[recent], algo4_pred[recent], label='algo4 (fit 2005–2024.5)')
ax.plot(years[recent], algo5_pred[recent], label='algo5 (fit 2005–2026.41 + SMH anchor)')
ax.set_xlabel('Year')
ax.set_ylabel('ΔT (s)')
ax.set_title('ΔT: algo5 vs algo4 on recent observations')
ax.legend()
ax.grid(alpha=0.3)
plt.show()

# %%
# #64 archive: the legacy dispatch (algo4 below 2035, algo2 above) jumps at the 2035
# seam; algo5's SMH-anchored extrapolation is smooth through it. algo4's domain ends
# at 2035, so its curve and the legacy composite only draw their valid spans.
future_years = np.arange(2020.0, 2051.0, 0.25)
pre = future_years < 2035.0

legacy = np.concatenate([vf_algo4(future_years[pre]), vf_algo2(future_years[~pre])])

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(future_years, vf_algo2(future_years), '--', alpha=0.6, label='algo2 (polynomial)')
ax.plot(future_years[pre], vf_algo4(future_years[pre]), '--', alpha=0.6,
        label='algo4 (fit, valid < 2035)')
ax.plot(future_years, legacy, 'r-', lw=1.2, label='legacy dispatch (algo4 → algo2 @2035)')
ax.plot(future_years, vf_algo5(future_years), 'g-', lw=1.5, label='algo5 (default)')
ax.axvline(2035.0, color='gray', lw=0.8, ls=':')
ax.set_xlabel('Year')
ax.set_ylabel('ΔT (s)')
ax.set_title('The retired 2035 seam vs algo5 smooth extrapolation (#64)')
ax.legend()
ax.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Conclusion
#
# - On USNO observations through 2026-04, algo5 tracks algo4's in-sample accuracy while
#   extending the fit to 2026.41 (see the metrics table and the recent-window plot).
# - The second plot archives #64: the retired default dispatch (algo4 below 2035, algo2
#   above) breaks at the 2035 seam, whereas algo5's SMH-anchored extrapolation passes
#   through it smoothly — the reason algo5 replaced the legacy dispatch.
